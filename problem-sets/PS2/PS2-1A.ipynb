# %% [markdown]
# ##### (a)

# %% [markdown]
# ```
# ==== Training model on data set A ====
# Finished 10000 iterations
# Finished 20000 iterations
# Finished 30000 iterations
# Converged in 30386 iterations
#
# ==== Training model on data set B ====
# Finished 10000 iterations
# Finished 20000 iterations
# Finished 30000 iterations
# Finished 40000 iterations
# ...
# ```

# %% [markdown]
# ##### (b)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import src.util as util

# %%
Xa, Ya = util.load_csv('data/ds1_a.csv', add_intercept=True)
Xb, Yb = util.load_csv('data/ds1_b.csv', add_intercept=True)

# %%
def plot(x, y, title):
    plt.figure()
    plt.plot(x[y==1, 1], x[y==1, 2], 'rx')
    plt.plot(x[y==-1, 1], x[y==-1, 2], 'bo')
    plt.suptitle(title, fontsize=12)

# %%
plot(Xa, Ya, "A")
plot(Xb, Yb, "B")

# %% [markdown]
# ##### (c)

# %% [markdown]
# i. no bc changes optimization algo when problem is w cost function
# ii. yes bc updates will grow beyond linear while trivial representation can only linear
# iii. no bc doesnt change fact of data being linearly seperable
# iv. yes will converge bc cannot keep trivially increasing size of parameter vector
# v. could help but prob not accurate

# %% [markdown]
# ##### (d)

# %% [markdown]
# $J(\hat{y}) = max(0, 1-y\cdot \hat{y})$ where $\hat{y}=w^Tx+b$
# thus when try to increase w or b so |y|>=1 then $J(\hat{y})=0 $
#
# aka past a certain geometric margin it no longer returns any gains for the functional margin
